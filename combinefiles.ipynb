# %%
import pandas as pd
import os

folder_path = 'data'
files = os.listdir(folder_path)
combined_df = pd.DataFrame()


for file in files:

    if file.startswith('Data_52') and file.endswith('.xlsx'):
            # Membaca file Excel ke dalam DataFrame
            df = pd.read_excel(os.path.join(folder_path, file))

            df['Price'] = df['Price'].str.replace(' IDR', '').astype(float)
            
            # Menggabungkan DataFrame
            combined_df = pd.concat([combined_df, df], ignore_index=True)

combined_df.to_excel('data52.xlsx', index=False)

# %%
combined_df
# Out:
#                                   Symbol    Price Change %    Volume  \
# 0                                    NaN      NaN      NaN       NaN
# 1         AARKAARKHA JAYANTI PERSADA TBK     50.0    0.00%    4.004M
# 2                  AARKOARKORA HYDRO TBK   1100.0  +18.28%   14.296M
# 3       BBAUTMITRA ANGKASA SEJAHTERA TBK     50.0    0.00%      7.1K
# 4         BBSIKROM BANK INDONESIA TBK PT   4500.0   +4.65%     28.4K
# 5    BBEKSBANK PEMBANGUNAN DAERAH BANTEN     50.0    0.00%    1.986M
# 6              BBLTABERLIAN LAJU TANKERS     50.0    0.00%        7K
# 7                 BNGABANK CIMB NIAGA TB   2120.0   +3.41%   14.667M
# 8         BRISBANK SYARIAH INDONESIA TBK   2510.0   +3.29%   53.286M
# 9            EELTYBAKRIELAND DEVELOPMENT     50.0    0.00%      1.4K
# 10        EENZOMORENZO ABADI PERKASA TBK     57.0   +3.64%    6.478M
# 11            FFORUFORTUNE INDONESIA TBK    740.0   +9.63%    578.9K
# 12                        JSMRJASA MARGA   5450.0   +3.81%   24.242M
# 13            KBAGKARYA BERSAMA ANUGERAH     50.0    0.00%      9.4K
# 14               KOTADMS PROPERTINDO TBK     50.0    0.00%     57.1K
# 15    KKRENQUANTUM CLOVERA INVESTAMA TBK     50.0    0.00%      2.3K
# 16               MMANGMANGGUNG POLAHRAYA    106.0   −3.64%   12.938M
# 17          MAPAMAP AKTIF ADIPERKASA TBK   1080.0    0.00%   45.429M
# 18            MMEJAHARTA DJAYA KARYA TBK    125.0   −0.79%  102.965M
# 19                  PPPROPP PROPERTI TBK     50.0    0.00%     13.2K
# 20        PURAPUTRA RAJAWALI KENCANA TBK     50.0    0.00%      6.1K
# 21       SSIASURYA SEMESTA INTERNUSA TBK    575.0   +2.68%    23.65M
# 22        TELEOMNI INOVASI INDONESIA TBK     50.0    0.00%      2.8K
# 23               VIVAVISI MEDIA ASIA TBK     50.0    0.00%       200
# 24     VVKTRVKTR TEKNOLOGI MOBILITAS TBK    224.0   −0.88%  779.766M
# 25         WINRWINNER NUSANTARA JAYA TBK     50.0    0.00%        6K
# 26           WOWSGINTING JAYA ENERGI TBK     50.0    0.00%       12K
# 27                                   NaN      NaN      NaN       NaN
# 28  ADMFADIRA DINAMIKA MULTI FINANCE TBK  13575.0   +2.07%    328.3K
# 29  AAHAPASURANSI HARTA AMAN PRATAMA TBK    172.0  +20.28%    161.3M
# 30        AARKAARKHA JAYANTI PERSADA TBK     50.0    0.00%       500
# 31                 AARKOARKORA HYDRO TBK   1115.0   +1.36%   21.338M
# 32      BBAUTMITRA ANGKASA SEJAHTERA TBK     50.0    0.00%      6.5K
# 33        BBSIKROM BANK INDONESIA TBK PT   4490.0   −0.22%       19K
# 34   BBEKSBANK PEMBANGUNAN DAERAH BANTEN     50.0    0.00%    444.4K
# 35  BBESSBATULICIN NUSANTARA MARITIM TBK    230.0   +7.48%   66.835M
# 36             BBLTABERLIAN LAJU TANKERS     50.0    0.00%    347.8K
# 37                BNGABANK CIMB NIAGA TB   2060.0   −2.83%   15.108M
# 38      BBSWDBANK OF INDIA INDONESIA TBK   1900.0   +8.57%       100
# 39  CCNKOEXPLOITASI ENERGI INDONESIA TBK     50.0    0.00%        1K
# 40           EELTYBAKRIELAND DEVELOPMENT     50.0    0.00%    317.2K
# 41            FFORUFORTUNE INDONESIA TBK    810.0   +9.46%    240.8K
# 42           ISATINDOSAT(PT INDOSAT TBK)  11250.0   +5.63%    6.034M
# 43                        JSMRJASA MARGA   5375.0   −1.38%    8.068M
# 44            KBAGKARYA BERSAMA ANUGERAH     50.0    0.00%       900
# 45               KOTADMS PROPERTINDO TBK     50.0    0.00%      2.2K
# 46               MMANGMANGGUNG POLAHRAYA    114.0   +7.55%   13.052M
# 47        PPDPPPRIMADAYA PLASTISINDO TBK    434.0   +0.93%     2.52M
# 48                  PPPROPP PROPERTI TBK     50.0    0.00%     11.2K
# 49        PURAPUTRA RAJAWALI KENCANA TBK     50.0    0.00%       100
# 50       SSIASURYA SEMESTA INTERNUSA TBK    565.0   −1.74%   24.458M
# 51        TELEOMNI INOVASI INDONESIA TBK     50.0    0.00%       400
# 52              VVISISATU VISI PUTRA TBK    140.0   −8.50%  556.518M
# 53               VIVAVISI MEDIA ASIA TBK     50.0    0.00%       100
# 54         WINRWINNER NUSANTARA JAYA TBK     50.0    0.00%     14.3K
# 55           WOWSGINTING JAYA ENERGI TBK     50.0    0.00%     10.2K
#
#    Rel Volume    Market cap     P/E   EPS dilTTM EPS dil growthTTM YoY  \
# 0         NaN           NaN     NaN          NaN                   NaN
# 1        7.74      100B IDR   18.19     2.75 IDR               −57.71%
# 2        1.25    2.138T IDR   50.48    21.79 IDR                     —
# 3        4.83  240.003B IDR   32.44     1.54 IDR                     —
# 4        0.99   15.643T IDR  142.34    31.61 IDR                     —
# 5        1.23    2.594T IDR   97.54     0.51 IDR                     —
# 6        0.12    1.295T IDR    5.22     9.58 IDR              +142.57%
# 7         0.7   51.106T IDR    8.17   259.44 IDR                     —
# 8        1.18  112.094T IDR   20.30   123.65 IDR                     —
# 9        0.06    2.176T IDR       —    −5.75 IDR              −219.70%
# 10       0.64   118.94B IDR  917.87     0.06 IDR               −98.22%
# 11       0.19  314.026B IDR       —    −6.38 IDR             −1239.02%
# 12       2.77   38.104T IDR    5.13  1062.89 IDR              +311.88%
# 13       0.45    357.5B IDR       —    −0.30 IDR              −124.75%
# 14       12.2  527.309B IDR       —    −1.75 IDR                +3.11%
# 15       0.09  910.292B IDR       —    −5.86 IDR               +10.90%
# 16       1.98             —       —            —                     —
# 17       1.93   30.784T IDR   21.86    49.41 IDR               +32.68%
# 18       1.09             —       —            —                     —
# 19       0.17    3.084T IDR       —    −1.66 IDR              −804.28%
# 20       0.22  315.097B IDR  115.50     0.43 IDR               −78.16%
# 21       0.82    2.547T IDR   32.17    17.88 IDR               −41.74%
# 22       0.17  365.546B IDR       —   −24.82 IDR                +7.23%
# 23       0.03  823.213B IDR       —   −91.48 IDR               +19.84%
# 24       1.49    9.888T IDR       —            —                     —
# 25       0.34             —       —            —                     —
# 26       0.58  123.786B IDR       —    −6.59 IDR               +71.60%
# 27        NaN           NaN     NaN          NaN                   NaN
# 28       1.08     12.8T IDR    6.98  1944.05 IDR                     —
# 29       1.61    690.9B IDR       —    −3.49 IDR              −292.21%
# 30       0.00      100B IDR   18.19     2.75 IDR               −57.71%
# 31       1.84    2.138T IDR   51.17    21.79 IDR                     —
# 32       3.04  240.003B IDR   32.44     1.54 IDR                     —
# 33       0.67   15.643T IDR  142.03    31.61 IDR                     —
# 34       0.25    2.594T IDR   97.54     0.51 IDR                     —
# 35      33.34  688.091B IDR       —            —                     —
# 36       5.73    1.295T IDR    5.22     9.58 IDR              +142.57%
# 37       0.81   51.106T IDR    7.94   259.44 IDR                     —
# 38       0.45    6.391T IDR  130.95    14.51 IDR                     —
# 39       0.02  447.818B IDR       —   −23.94 IDR              −275.66%
# 40      87.14    2.176T IDR       —    −5.75 IDR              −219.70%
# 41       0.14  314.026B IDR       —    −6.38 IDR             −1239.02%
# 42       0.95   85.868T IDR   20.13   558.92 IDR                −4.62%
# 43       0.74   38.104T IDR    5.06  1062.89 IDR              +311.88%
# 44       0.04    357.5B IDR       —    −0.30 IDR              −124.75%
# 45       0.21  527.309B IDR       —    −1.75 IDR                +3.11%
# 46       1.81             —       —            —                     —
# 47       0.38    1.304T IDR       —            —                     —
# 48       0.14    3.084T IDR       —    −1.66 IDR              −804.28%
# 49       0.00  315.097B IDR  115.50     0.43 IDR               −78.16%
# 50       0.85    2.547T IDR   31.61    17.88 IDR               −41.74%
# 51       0.02  365.546B IDR       —   −24.82 IDR                +7.23%
# 52          —             —       —            —                     —
# 53       0.02  823.213B IDR       —   −91.48 IDR               +19.84%
# 54       1.25             —       —            —                     —
# 55       0.47  123.786B IDR       —    −6.59 IDR               +71.60%
#
#    Div yield %TTM                 Sector Analyst Rating
# 0             NaN                    NaN            NaN
# 1           0.00%         Transportation              —
# 2           0.00%    Industrial Services     Strong buy
# 3           0.54%  Distribution Services              —
# 4           0.00%                Finance              —
# 5           0.00%                Finance              —
# 6           0.00%         Transportation              —
# 7           5.62%                Finance            Buy
# 8           0.38%                Finance     Strong buy
# 9           0.00%                Finance              —
# 10          0.00%  Consumer Non-Durables              —
# 11          0.00%    Commercial Services              —
# 12          1.44%         Transportation     Strong buy
# 13          0.00%                Finance              —
# 14          0.00%                Finance              —
# 15          0.00%                Finance              —
# 16              —      Consumer Durables              —
# 17          0.37%           Retail Trade     Strong buy
# 18              —    Commercial Services              —
# 19          0.00%                Finance              —
# 20          0.00%         Transportation              —
# 21          0.00%    Industrial Services     Strong buy
# 22          0.00%  Distribution Services              —
# 23          0.00%      Consumer Services              —
# 24          0.00%      Consumer Durables              —
# 25              —                Finance              —
# 26          0.00%    Industrial Services              —
# 27            NaN                    NaN            NaN
# 28          6.27%                Finance     Strong buy
# 29          0.00%                Finance              —
# 30          0.00%         Transportation              —
# 31          0.00%    Industrial Services     Strong buy
# 32          0.54%  Distribution Services              —
# 33          0.00%                Finance              —
# 34          0.00%                Finance              —
# 35          0.00%         Transportation              —
# 36          0.00%         Transportation              —
# 37          5.62%                Finance            Buy
# 38          0.00%                Finance              —
# 39          0.00%        Energy Minerals              —
# 40          0.00%                Finance              —
# 41          0.00%    Commercial Services              —
# 42          2.40%         Communications     Strong buy
# 43          1.44%         Transportation     Strong buy
# 44          0.00%                Finance              —
# 45          0.00%                Finance              —
# 46              —      Consumer Durables              —
# 47          0.61%     Process Industries              —
# 48          0.00%                Finance              —
# 49          0.00%         Transportation              —
# 50          0.00%    Industrial Services     Strong buy
# 51          0.00%  Distribution Services              —
# 52              —                      —              —
# 53          0.00%      Consumer Services              —
# 54              —                Finance              —
# 55          0.00%    Industrial Services              —
